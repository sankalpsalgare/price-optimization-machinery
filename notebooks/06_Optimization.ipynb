# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

import pandas as pd
import matplotlib.pyplot as plt

from src.elasticity.elasticity import *
from src.optimization.optimization import *
from src.config.config import *

# %%
df = pd.read_csv(
    "../data/processed/indian_machinery_transaction_data_3.csv",
    parse_dates=["invoice_date"]
)

df.head()
# Out:
#    invoice_id invoice_date  year  month  season customer_type    brand  \
# 0      500001   2019-01-01  2019      1  Winter        Retail  Supreme
# 1      500061   2019-01-01  2019      1  Winter        Retail     Jain
# 2      500060   2019-01-01  2019      1  Winter    Contractor     Jain
# 3      500059   2019-01-01  2019      1  Winter        Farmer     Jain
# 4      500058   2019-01-01  2019      1  Winter        Retail     Jain
#
#     product_name product_category specification  quantity      mrp  \
# 0       PVC Pipe             Pipe      0.5 inch         1    89.61
# 1  Sprinkler Set       Irrigation    Heavy Duty         2  2257.78
# 2  Sprinkler Set       Irrigation          Mini         2  1446.31
# 3  Sprinkler Set       Irrigation          Mini         1  1446.31
# 4  Sprinkler Set       Irrigation          Mini         3  1446.31
#
#    selling_price  unit_cost  discount_pct  revenue  profit
# 0          83.49      70.69          6.83    83.49   12.80
# 1        2224.77    1902.32          1.46  4449.54  644.90
# 2        1334.39    1222.70          7.74  2668.78  223.38
# 3        1195.99    1021.78         17.31  1195.99  174.21
# 4        1423.58    1200.86          1.57  4270.74  668.16

# %%
base_data_df=optimization_dataprep(df,date_col="invoice_date",n_weeks=10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Pricing_Optimizer\env\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'discount_pct'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 base_data_df=optimization_dataprep(df,date_col="invoice_date",n_weeks=10)
#
# File d:\Pricing_Optimizer\src\optimization\optimization.py:102, in optimization_dataprep(df, date_col, n_weeks, product_name_col, specification_col, product_id_col)
#     100 agg_df["revenue"]=agg_df["revenue"].astype(int)
#     101 agg_df["profit"]=agg_df["profit"].astype(int)
# --> 102 agg_df["discount_pct"]=agg_df["discount_pct"].astype(int)
#     103 return agg_df
#
# File d:\Pricing_Optimizer\env\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File d:\Pricing_Optimizer\env\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'discount_pct'

# %%
elasticity_df=pd.read_csv(
    "../data/external/elasticity.csv"
)

# %%
final_base_data_df=base_data_df.merge(elasticity_df[['product_id','price_elasticity']],on='product_id',how='left')

# %%
optimized_df = optimize_revenue_dataframe(
    final_base_data_df,
    config=PRICING_CONSTRAINTS,
    n_iterations=200
)

# %%
optimized_df
# Out:
#                          product_id    category    base_price  \
# 0               cpvc_pipe__1_5_inch        Pipe    366.974893
# 1                 cpvc_pipe__1_inch        Pipe    256.317458
# 2                 cpvc_pipe__2_inch        Pipe    518.757004
# 3     drip_irrigation_kit__0_5_acre  Irrigation   1207.939227
# 4       drip_irrigation_kit__1_acre  Irrigation   2023.752140
# 5       drip_irrigation_kit__2_acre  Irrigation   3513.373125
# 6                foot_valve__1_inch     Fitting    407.554463
# 7   motor_pump__0_5_hp_single_phase       Motor  10812.506109
# 8   motor_pump__1_5_hp_single_phase       Motor  17802.940333
# 9     motor_pump__1_hp_single_phase       Motor  14495.306992
# 10    motor_pump__2_hp_single_phase       Motor  21897.986531
# 11     motor_pump__3_hp_three_phase       Motor  33151.773957
# 12     motor_pump__5_hp_three_phase       Motor  54443.641646
# 13             pipe_clamp__standard     Fitting     22.944408
# 14              pvc_coupler__1_inch     Fitting     38.263305
# 15              pvc_elbow__0_5_inch     Fitting     31.856327
# 16                pvc_elbow__1_inch     Fitting     44.291807
# 17              pvc_end_cap__1_inch     Fitting     25.663504
# 18               pvc_pipe__0_5_inch        Pipe    127.634398
# 19              pvc_pipe__0_75_inch        Pipe    150.043771
# 20              pvc_pipe__1_25_inch        Pipe    206.395394
# 21               pvc_pipe__1_5_inch        Pipe    240.436128
# 22                 pvc_pipe__1_inch        Pipe    171.242456
# 23               pvc_pipe__2_5_inch        Pipe    428.471093
# 24                 pvc_pipe__2_inch        Pipe    315.736883
# 25                 pvc_pipe__3_inch        Pipe    544.746220
# 26                 pvc_pipe__4_inch        Pipe    883.615106
# 27                 pvc_pipe__6_inch        Pipe   1386.029253
# 28                  pvc_tee__1_inch     Fitting     56.863859
# 29                pvc_union__1_inch     Fitting     82.391064
# 30        sprinkler_set__heavy_duty  Irrigation   2959.529437
# 31              sprinkler_set__mini  Irrigation   1867.516255
# 32            thread_tape__standard     Fitting     15.469099
#
#     optimized_price  base_units  optimized_units  base_revenue  \
# 0            376.85         940           933.27     346481.68
# 1            266.32         940           937.83     240745.58
# 2            528.75         968           968.24     501017.00
# 3           1217.89         989           987.20    1196261.85
# 4           2033.72         939           937.39    1903357.40
# 5           3523.30         944           944.10    3300826.75
# 6            417.53         946           935.52     385121.47
# 7          11012.39         975           974.60   10544247.19
# 8          18002.63         953           952.64   17113812.85
# 9          14694.36         953           947.39   13769913.72
# 10         22093.69         969           968.51   21409796.03
# 11         33351.38         908           913.10   30159405.19
# 12         54642.42         931           931.23   50611097.39
# 13            25.23         894           895.12      20622.28
# 14            42.08        1015          1005.42      38817.27
# 15            35.04         906           908.64      29154.00
# 16            48.70         910           918.98      40196.37
# 17            28.21         901           891.31      23063.91
# 18           137.63         957           930.00     122958.79
# 19           159.88         931           912.96     139986.67
# 20           216.39         922           910.30     190716.44
# 21           250.42         993           973.17     238021.40
# 22           181.18         930           938.83     159766.39
# 23           438.41         897           897.07     381438.73
# 24           325.69        1013          1004.07     322705.67
# 25           554.73         983           975.12     537941.75
# 26           893.51         911           909.41     808770.03
# 27          1395.99         961           961.89    1329433.18
# 28            62.52         965           919.30      54622.60
# 29            90.63         921           915.82      76252.46
# 30          2969.49         920           919.69    2703521.79
# 31          1877.50         939           936.18    1751589.24
# 32            17.01         982           967.30      15274.64
#
#     optimized_revenue  revenue_change_pct
# 0           351706.30              0.0196
# 1           249758.86              0.0366
# 2           511957.91              0.0195
# 3          1202303.61              0.0064
# 4          1906392.22              0.0032
# 5          3326359.09              0.0029
# 6           390607.09              0.0131
# 7         10732659.81              0.0181
# 8         17149968.42              0.0108
# 9         13921246.92              0.0078
# 10        21397866.05              0.0084
# 11        30453109.37              0.0117
# 12        50884584.24              0.0039
# 13           22586.62              0.1011
# 14           42306.82              0.0893
# 15           31839.08              0.1032
# 16           44756.18              0.1104
# 17           25140.86              0.0873
# 18          127996.07              0.0479
# 19          145961.85              0.0449
# 20          196975.11              0.0351
# 21          243702.59              0.0207
# 22          170094.66              0.0681
# 23          393287.09              0.0233
# 24          327018.81              0.0224
# 25          540926.48              0.0102
# 26          812562.84              0.0094
# 27         1342783.67              0.0081
# 28           57474.36              0.0474
# 29           82999.38              0.0938
# 30         2731007.28              0.0030
# 31         1757670.30              0.0023
# 32           16453.75              0.0831

# %%
optimized_df.to_csv('../data/external/optimized_data.csv',index=False)
